# %% [markdown]
# ## Парс категорий

# %%
from bs4 import BeautifulSoup

with open("Всезадания.html", encoding="utf8") as fp:
    soup = BeautifulSoup(fp, "html.parser")

# %%
nodes = soup.find_all("div", class_="Categories_catName__3MAsf")
nodes
# Out:
# [<div class="Categories_catName__3MAsf">Курьерские услуги<span class="Categories_catCount__-HfdW hidden"> [8]</span></div>,
#  <div class="Categories_catName__3MAsf">Ремонт и строительство<span class="Categories_catCount__-HfdW hidden"> [19]</span></div>,
#  <div class="Categories_catName__3MAsf">Грузоперевозки<span class="Categories_catCount__-HfdW hidden"> [10]</span></div>,
#  <div class="Categories_catName__3MAsf">Уборка и помощь по хозяйству<span class="Categories_catCount__-HfdW hidden"> [14]</span></div>,
#  <div class="Categories_catName__3MAsf">Виртуальный помощник<span class="Categories_catCount__-HfdW hidden"> [12]</span></div>,
#  <div class="Categories_catName__3MAsf">Компьютерная помощь<span class="Categories_catCount__-HfdW hidden"> [9]</span></div>,
#  <div class="Categories_catName__3MAsf">Мероприятия и промоакции<span class="Categories_catCount__-HfdW hidden"> [10]</span></div>,
# ...

# %%
catnames = []
for i in nodes:
    catnames.append(i.contents[0])

# %%
catnames
# Out:
# ['Курьерские услуги',
#  'Ремонт и строительство',
#  'Грузоперевозки',
#  'Уборка и помощь по хозяйству',
#  'Виртуальный помощник',
#  'Компьютерная помощь',
#  'Мероприятия и промоакции',
#  'Дизайн',
#  'Разработка ПО',
#  'Фото, видео и аудио',
#  'Установка и ремонт техники',
#  'Красота и здоровье',
#  'Ремонт цифровой техники',
#  'Юридическая и бухгалтерская помощь',
#  'Репетиторы и обучение',
#  'Ремонт транспорта']

# %%
# filling categories
import random
import psycopg2

conn = psycopg2.connect(user='postgres', password='1234', host='localhost', port='5432', database="youdo")
cur = conn.cursor()

cat_names = catnames

for i in range(0, len(cat_names)):
    query = f"INSERT INTO category(\"name\")"\
            f" VALUES ('{cat_names[i]}');"
    cur.execute(query)
    
conn.commit()
cur.close()
conn.close()

# %%
count = len(catnames)
count
# Out:
# 16

# %%
# filling estimated cost for all categories

conn = psycopg2.connect(user='postgres', password='1234', host='localhost', port='5432', database="youdo")
cur = conn.cursor()

arr = []

for i in range(1, count):
    arr.append(i + 50)

# courier service
query = f"INSERT INTO estimated_cost(interval_begin, interval_end, response_cost, category_id) VALUES "\
f"(500, 600, 29, {arr[0]}), "\
f"(null, 500, 11, {arr[0]}), "\
f"(800, 1200, 60, {arr[0]}), "\
f"(1200, 1500, 99, {arr[0]}), "\
f"(1500, 2500, 141, {arr[0]}), "\
f"(2500, null, 199, {arr[0]}), "\
f"(600, 800, 42, {arr[0]}); "
cur.execute(query)

# repair and construction
query = f"INSERT INTO estimated_cost(interval_begin, interval_end, response_cost, category_id) VALUES "\
f"(null, 3000, 62, {arr[1]}), "\
f"(3000, 5000, 80, {arr[1]}), "\
f"(5000, 10000, 100, {arr[1]}), "\
f"(10000, 36000, 137, {arr[1]}), "\
f"(36000, null, 200, {arr[1]}); "
cur.execute(query)

# trucking
query = f"INSERT INTO estimated_cost(interval_begin, interval_end, response_cost, category_id) VALUES "\
f"(null, 2000, 30, {arr[2]}), "\
f"(2000, 5000, 50, {arr[2]}), "\
f"(5000, 8000, 80, {arr[2]}), "\
f"(8000, 15000, 100, {arr[2]}), "\
f"(15000, 24000, 131, {arr[2]}), "\
f"(24000, null, 199, {arr[2]});"
cur.execute(query)

# cleaning and housekeeping assistance
query = f"INSERT INTO estimated_cost(interval_begin, interval_end, response_cost, category_id) VALUES "\
f"(null, 1500, 38, {arr[3]}), "\
f"(1500, 3000, 53, {arr[3]}), "\
f"(3000, 5000, 76, {arr[3]}), "\
f"(5000, 8000, 91, {arr[3]}), "\
f"(8000, null, 109, {arr[3]});"
cur.execute(query)

# virtual assistant
query = f"INSERT INTO estimated_cost(interval_begin, interval_end, response_cost, category_id) VALUES "\
f"(null, 1000, 20, {arr[4]}), "\
f"(1000, 3000, 50, {arr[4]}), "\
f"(3000, 8000, 100, {arr[4]}), "\
f"(8000, 10000, 155, {arr[4]}), "\
f"(10000, null, 250, {arr[4]});"
cur.execute(query)

# computer help
query = f"INSERT INTO estimated_cost(interval_begin, interval_end, response_cost, category_id) VALUES "\
f"(null, 500, 30, {arr[5]}), "\
f"(500, 1500, 50, {arr[5]}), "\
f"(1500, 2500, 66, {arr[5]}), "\
f"(2500, 3500, 81, {arr[5]}), "\
f"(3500, null, 101, {arr[5]});"
cur.execute(query)

# events and promotions
query = f"INSERT INTO estimated_cost(interval_begin, interval_end, response_cost, category_id) VALUES "\
f"(null, 500, 22, {arr[6]}), "\
f"(500, 3500, 50, {arr[6]}), "\
f"(3500, 5000, 74, {arr[6]}), "\
f"(5000, 10000, 98, {arr[6]}), "\
f"(10000, null, 124, {arr[6]});"
cur.execute(query)

# design
query = f"INSERT INTO estimated_cost(interval_begin, interval_end, response_cost, category_id) VALUES "\
f"(null, 500, 26, {arr[7]}), "\
f"(500, 1500, 36, {arr[7]}), "\
f"(1500, 5000, 54, {arr[7]}), "\
f"(5000, 10000, 98, {arr[7]}), "\
f"(10000, 50000, 150, {arr[7]}), "\
f"(50000, null, 299, {arr[7]});"
cur.execute(query)

# software development
query = f"INSERT INTO estimated_cost(interval_begin, interval_end, response_cost, category_id) VALUES "\
f"(null, 1500, 57, {arr[8]}), "\
f"(1500, 5000, 80, {arr[8]}), "\
f"(5000, 10000, 90, {arr[8]}), "\
f"(10000, 25000, 122, {arr[8]}), "\
f"(25000, 50000, 150, {arr[8]}), "\
f"(50000, 100000, 180, {arr[8]}), "\
f"(100000, 150000, 201, {arr[8]}), "\
f"(150000, null, 299, {arr[8]});"
cur.execute(query)

# photo, video and audio
query = f"INSERT INTO estimated_cost(interval_begin, interval_end, response_cost, category_id) VALUES "\
f"(null, 500, 57, {arr[9]}), "\
f"(500, 1500, 69, {arr[9]}), "\
f"(1500, 3000, 90, {arr[9]}), "\
f"(3000, 6000, 126, {arr[9]}), "\
f"(6000, 15000, 185, {arr[9]}), "\
f"(15000, 25000, 256, {arr[9]}), "\
f"(25000, null, 298, {arr[9]});"
cur.execute(query)

# installation and repair of equipment
query = f"INSERT INTO estimated_cost(interval_begin, interval_end, response_cost, category_id) VALUES "\
f"(null, 1000, 53, {arr[10]}), "\
f"(1000, 2000, 70, {arr[10]}), "\
f"(2000, 5000, 90, {arr[10]}), "\
f"(5000, 10000, 134, {arr[10]}), "\
f"(10000, 15000, 187, {arr[10]}), "\
f"(15000, 30000, 256, {arr[10]}), "\
f"(30000, null, 289, {arr[10]});"
cur.execute(query)

# beauty and health
query = f"INSERT INTO estimated_cost(interval_begin, interval_end, response_cost, category_id) VALUES "\
f"(null, 500, 32, {arr[11]}), "\
f"(500, 1500, 50, {arr[11]}), "\
f"(1500, 3000, 70, {arr[11]}), "\
f"(3000, 5000, 121, {arr[11]}), "\
f"(5000, 15000, 240, {arr[11]}), "\
f"(15000, null, 300, {arr[11]});"
cur.execute(query)

# digital equipment repair
query = f"INSERT INTO estimated_cost(interval_begin, interval_end, response_cost, category_id) VALUES "\
f"(null, 1500, 34, {arr[12]}), "\
f"(1500, 3000, 58, {arr[12]}), "\
f"(3000, 10000, 70, {arr[12]}), "\
f"(10000, null, 123, {arr[12]});"
cur.execute(query)

# legal and accounting assistance
query = f"INSERT INTO estimated_cost(interval_begin, interval_end, response_cost, category_id) VALUES "\
f"(null, 500, 34, {arr[13]}), "\
f"(500, 1500, 58, {arr[13]}), "\
f"(1500, 5000, 100, {arr[13]}), "\
f"(5000, 7000, 165, {arr[13]}), "\
f"(7000, 15000, 241, {arr[13]}), "\
f"(15000, 40000, 357, {arr[13]}), "\
f"(40000, null, 456, {arr[13]});"
cur.execute(query)

# contracts, documents, courts, taxes
query = f"INSERT INTO estimated_cost(interval_begin, interval_end, response_cost, category_id) VALUES "\
f"(null, 1000, 50, {arr[14]}), "\
f"(1000, 3000, 123, {arr[14]}), "\
f"(3000, 10000, 254, {arr[14]}), "\
f"(10000, null, 368, {arr[14]});"
cur.execute(query)

conn.commit()
cur.close()
conn.close()

"""

# transport repair
query = f"INSERT INTO estimated_cost(interval_begin, interval_end, response_cost, category_id) VALUES "\
f"(null, 1500, 50, {arr[15]}), "\
f"(1500, 5000, 83, {arr[15]}), "\
f"(5000, 10000, 124, {arr[15]}), "\
f"(10000, 50000, 250, {arr[15]}), "\
f"(50000, null, 400, {arr[15]});"
cur.execute(query)

# studying
query = f"INSERT INTO estimated_cost(interval_begin, interval_end, response_cost, category_id) VALUES "\
f"(null, 1500, 100, {arr[16]}), "\
f"(1500, 5000, 200, {arr[16]}), "\
f"(5000, null, 500, {arr[16]});"
cur.execute(query)

"""
# Out:
# '\n\n# transport repair\nquery = f"INSERT INTO estimated_cost(interval_begin, interval_end, response_cost, category_id) VALUES "f"(null, 1500, 50, {arr[15]}), "f"(1500, 5000, 83, {arr[15]}), "f"(5000, 10000, 124, {arr[15]}), "f"(10000, 50000, 250, {arr[15]}), "f"(50000, null, 400, {arr[15]});"\ncur.execute(query)\n\n# studying\nquery = f"INSERT INTO estimated_cost(interval_begin, interval_end, response_cost, category_id) VALUES "f"(null, 1500, 100, {arr[16]}), "f"(1500, 5000, 200, {arr[16]}), "f"(5000, null, 500, {arr[16]});"\ncur.execute(query)\n\nconn.commit()\ncur.close()\nconn.close()\n\n'

# %% [markdown]
# ## Парс задач

# %%
from bs4 import BeautifulSoup
import requests
import lxml
import regex as re

# %%
url = 'https://youdo.com/api/tasks/tasks/'
headers = {
    'content-encoding' : 'br',
    'content-type': 'application/json; charset=utf-8'
}
r = requests.post(url, headers=headers)
res = r.text

# %%
res = '{"ResultObject":{"Items":[{"Id":11321704,"Name":"Ремонт (чистка) принтера","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"computerhelp","Address":"Новинский бульвар, 11Ас1, Москва","Url":"/t11321704","DateTimeString":"Начать 16 мая, 14:00","DateString":"Начать 16 мая","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":126069192,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=0\u0026AvatarType=H60W60","Rating":{"PositiveReviews":49,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":49},"UserName":"Мария"},"Viewed":false,"IsRegular":false,"PriceRangeId":12786,"BudgetDescription":"до 2 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":2.24,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321703,"Name":"Вечерняя няня для ребенка","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"house","Address":"улица Столетова, 7к1, Москва","Url":"/t11321703","DateTimeString":"15 мая, 21:00 — 15 мая, 23:55","DateString":"15 мая — 15 мая","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":126684589,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=0\u0026AvatarType=H60W60","Rating":{"PositiveReviews":49,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":49},"UserName":"Оксана"},"Viewed":false,"IsRegular":false,"PriceRangeId":12035,"BudgetDescription":"до 2 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":9.211,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321702,"Name":"Продвижение на магазина на OZON","IsMarker":false,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"virtualassistant","Address":null,"Url":"/t11321702","DateTimeString":"Начать 16 мая, 0:00","DateString":"Начать 16 мая","HideTime":true,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":132478645,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=0\u0026AvatarType=H60W60","Rating":{"PositiveReviews":0,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":0},"UserName":"Анастасия"},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 25 000","IsSbr":false,"Admission":null,"IsB2B":true,"OffersCount":0,"Distance":null,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321490,"Name":"Временная Регстрация","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"legaladvice","Address":"Москва","Url":"/t11321490","DateTimeString":"Начать 16 мая, 16:45","DateString":"Начать 16 мая","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":129060131,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=0\u0026AvatarType=H60W60","Rating":{"PositiveReviews":0,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":0},"UserName":"Мохамед"},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 7 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":0,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321701,"Name":"Выбросить мусор","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"house","Address":"Дмитровский проезд, 6к1, Москва","Url":"/t11321701","DateTimeString":"Начать 15 мая, 17:15","DateString":"Начать 15 мая","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":123868649,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=7638103\u0026AvatarType=H60W60","Rating":{"PositiveReviews":26,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":26},"UserName":"Анна Э."},"Viewed":false,"IsRegular":false,"PriceRangeId":13480,"BudgetDescription":"до 1 500","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":6.553,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321700,"Name":"Установить кондиционер в квартире","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"techrepair","Address":"улица Академика Варги, Москва","Url":"/t11321700","DateTimeString":"Начать 17 мая, 0:00","DateString":"Начать 17 мая","HideTime":true,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":126016251,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=791270\u0026AvatarType=H60W60","Rating":{"PositiveReviews":35,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":35},"UserName":"Сергей Г."},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 12 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":16.563,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321699,"Name":"Мастер по ремонту стиральных машин","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"techrepair","Address":"улица Рогожский Вал, Москва","Url":"/t11321699","DateTimeString":"Начать 18 мая, 17:40","DateString":"Начать 18 мая","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":126767599,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=5905541\u0026AvatarType=H60W60","Rating":{"PositiveReviews":18,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":18},"UserName":"Николай Н."},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 15 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":3.925,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321696,"Name":"Аренда курьера на легковом авто на постоянную основу...","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"courier","Address":"Нижняя улица, 14с4, Москва","Url":"/t11321696","DateTimeString":"15 мая, 17:39 — 15 июня, 23:59","DateString":"15 мая — 15 июня","HideTime":true,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":132579048,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=0\u0026AvatarType=H60W60","Rating":{"PositiveReviews":0,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":0},"UserName":"Зарина"},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 50 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":3.642,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321695,"Name":"Помощник инженера ПТО, работа с Исполнительной документацие...","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"clerical","Address":"метро Селигерская, Москва","Url":"/t11321695","DateTimeString":"16 мая, 10:00 — 9 августа, 17:35","DateString":"16 мая — 9 августа","HideTime":false,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":130790478,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=6001571\u0026AvatarType=H60W60","Rating":{"PositiveReviews":0,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":0},"UserName":"Татьяна С."},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 20 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":13.075,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321693,"Name":"Небольшая уборка квартиры","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"house","Address":"улица Героев Панфиловцев, 27к2, Москва","Url":"/t11321693","DateTimeString":"16 мая, 19:30 — 17 мая, 19:30","DateString":"16 мая — 17 мая","HideTime":false,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":132579039,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=0\u0026AvatarType=H60W60","Rating":{"PositiveReviews":0,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":0},"UserName":"One T."},"Viewed":false,"IsRegular":true,"PriceRangeId":1,"BudgetDescription":"до 2 400","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":16.837,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321692,"Name":"Фотошоп. Наложение логотип на товар","IsMarker":false,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"virtualassistant","Address":null,"Url":"/t11321692","DateTimeString":"Начать 16 мая, 0:00","DateString":"Начать 16 мая","HideTime":true,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":121630566,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=0\u0026AvatarType=H60W60","Rating":{"PositiveReviews":0,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":0},"UserName":"Katuyha"},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до  300","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":null,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321691,"Name":"Нужно следить за софтом, который автоматически делает...","IsMarker":false,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"virtualassistant","Address":null,"Url":"/t11321691","DateTimeString":"Начать 16 мая, 0:00","DateString":"Начать 16 мая","HideTime":true,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":132366985,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=7823984\u0026AvatarType=H60W60","Rating":{"PositiveReviews":0,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":0},"UserName":"Влад С."},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 50 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":null,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321688,"Name":"Ген уборка офиса 550 кв м : помыть офис , окна","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"house","Address":"улица Бутырский Вал, Москва","Url":"/t11321688","DateTimeString":"Начать 22 мая, 10:00","DateString":"Начать 22 мая","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":126807471,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=5850338\u0026AvatarType=H60W60","Rating":{"PositiveReviews":12,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":12},"UserName":"Оксана Г."},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 10 000","IsSbr":true,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":3.627,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321684,"Name":"Татуаж бровей","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"healthandbeauty","Address":"метро Улица Академика Янгеля, Москва","Url":"/t11321684","DateTimeString":"Начать 16 мая, 0:00","DateString":"Начать 16 мая","HideTime":true,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":128046661,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=4987454\u0026AvatarType=H60W60","Rating":{"PositiveReviews":0,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":0},"UserName":"Ольга С."},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 3 600","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":17.886,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321683,"Name":"Выложить обьявление на авито","IsMarker":false,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"virtualassistant","Address":null,"Url":"/t11321683","DateTimeString":"Начать 15 мая, 18:10","DateString":"Начать 15 мая","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":132578535,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=0\u0026AvatarType=H60W60","Rating":{"PositiveReviews":0,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":0},"UserName":"Вова"},"Viewed":false,"IsRegular":false,"PriceRangeId":13170,"BudgetDescription":"до 1 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":null,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321682,"Name":"Возвести перегородку","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"clerical","Address":"микрорайон Павшино, Красногорск","Url":"/t11321682","DateTimeString":"Начать 3 июня, 8:35","DateString":"Начать 3 июня","HideTime":false,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":127857793,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=6712436\u0026AvatarType=H60W60","Rating":{"PositiveReviews":0,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":0},"UserName":"Аида К."},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 18 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":17.93,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321681,"Name":"Прикурить машину, проводов нет","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"auto","Address":"Милютинский переулок, 5, Москва","Url":"/t11321681","DateTimeString":"Начать 15 мая, 18:11","DateString":"Начать 15 мая","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":125515510,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=6449852\u0026AvatarType=H60W60","Rating":{"PositiveReviews":1,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":1},"UserName":"Vladimir S."},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 1 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":1.085,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321680,"Name":"Помыть окна в квартире","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"house","Address":"улица Верхние Поля, 6, Москва","Url":"/t11321680","DateTimeString":"18 мая, 17:35 — 21 мая, 17:40","DateString":"18 мая — 21 мая","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":121529304,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=1272971\u0026AvatarType=H60W60","Rating":{"PositiveReviews":4,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":4},"UserName":"Сергей И."},"Viewed":false,"IsRegular":false,"PriceRangeId":13357,"BudgetDescription":"до 3 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":13.139,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321679,"Name":"Необходима помощь юриста","IsMarker":false,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"legaladvice","Address":null,"Url":"/t11321679","DateTimeString":"Начать 15 мая, 17:35","DateString":"Начать 15 мая","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":125885014,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=6651083\u0026AvatarType=H60W60","Rating":{"PositiveReviews":3,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":3},"UserName":"Федор П."},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 1 200","IsSbr":true,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":null,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321097,"Name":"Привезти груз 13 кг Люберцы, ул 65 лет - Москва, Алтуфьевск...","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"courier","Address":"улица 65 лет Победы, 1литЦ, Люберцы","Url":"/t11321097","DateTimeString":"Начать 16 мая, 9:00","DateString":"Начать 16 мая","HideTime":false,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":130593432,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=6039344\u0026AvatarType=H60W60","Rating":{"PositiveReviews":48,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":48},"UserName":"Павел Н."},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до  700","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":18.55,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321434,"Name":"Диагностика контроллера СКУД Cotag","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"techrepair","Address":"Манежная площадь, 1, Москва","Url":"/t11321434","DateTimeString":"Начать 16 мая, 0:00","DateString":"Начать 16 мая","HideTime":true,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":132578865,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=0\u0026AvatarType=H60W60","Rating":{"PositiveReviews":0,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":0},"UserName":"Игорь В."},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 3 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":0.432,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321660,"Name":"Нужен человек со знанием английского языка для перевода...","IsMarker":false,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"virtualassistant","Address":null,"Url":"/t11321660","DateTimeString":"Начать 19 мая, 12:00","DateString":"Начать 19 мая","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":132578560,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=0\u0026AvatarType=H60W60","Rating":{"PositiveReviews":0,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":0},"UserName":"Александр К."},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 8 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":null,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321676,"Name":"Пеший курьер","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"courier","Address":"Новочерёмушкинская улица, 41к2, Москва","Url":"/t11321676","DateTimeString":"Начать 15 мая, 17:35","DateString":"Начать 15 мая","HideTime":false,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":132504704,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=7889837\u0026AvatarType=H60W60","Rating":{"PositiveReviews":2,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":2},"UserName":"Натали К."},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до  500","IsSbr":true,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":9.374,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321674,"Name":"Занять беседку на Борисовских прудах","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"courier","Address":"улица Борисовские Пруды, Москва","Url":"/t11321674","DateTimeString":"Начать 10 июня, 3:00","DateString":"Начать 10 июня","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":124895932,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=7829659\u0026AvatarType=H60W60","Rating":{"PositiveReviews":18,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":18},"UserName":"Татьяна Н."},"Viewed":false,"IsRegular":false,"PriceRangeId":13518,"BudgetDescription":"до 1 800","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":15.338,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321673,"Name":"Необходимо настроить принтер","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"computerhelp","Address":"Зеленоград, 2304, Зеленоград","Url":"/t11321673","DateTimeString":"Начать 15 мая, 17:30","DateString":"Начать 15 мая","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":124232223,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=0\u0026AvatarType=H60W60","Rating":{"PositiveReviews":16,"NegativeReviews":1,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":17},"UserName":"Мила"},"Viewed":false,"IsRegular":false,"PriceRangeId":12785,"BudgetDescription":"до 1 250","IsSbr":true,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":35.529,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321672,"Name":"Нужен переводчик с английского на русский","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"virtualassistant","Address":"деревня Аносино","Url":"/t11321672","DateTimeString":"22 мая, 0:00 — 26 мая, 23:59","DateString":"22 мая — 26 мая","HideTime":true,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":132377850,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=0\u0026AvatarType=H60W60","Rating":{"PositiveReviews":1,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":1},"UserName":"Егор"},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 4 000","IsSbr":false,"Admission":null,"IsB2B":true,"OffersCount":0,"Distance":38.864,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321671,"Name":"Написать вкр по психологии (магистр)","IsMarker":false,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"teaching","Address":null,"Url":"/t11321671","DateTimeString":"Начать 15 мая, 17:30","DateString":"Начать 15 мая","HideTime":false,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":123415126,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=0\u0026AvatarType=H60W60","Rating":{"PositiveReviews":0,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":0},"UserName":"Маргарита Ш."},"Viewed":false,"IsRegular":true,"PriceRangeId":1,"BudgetDescription":"до 30 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":null,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321669,"Name":"Рассчитать эффективность госпрограммы по формуле","IsMarker":false,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"teaching","Address":null,"Url":"/t11321669","DateTimeString":"15 мая, 17:30 — 16 мая, 20:00","DateString":"15 мая — 16 мая","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":131845974,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=7619579\u0026AvatarType=H60W60","Rating":{"PositiveReviews":2,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":2},"UserName":"Polina"},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 1 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":null,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321668,"Name":"Создание твердотельных моделей по 3d сканам","IsMarker":false,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"design","Address":null,"Url":"/t11321668","DateTimeString":"Начать 15 мая, 17:30","DateString":"Начать 15 мая","HideTime":false,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":129774587,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=6184291\u0026AvatarType=H60W60","Rating":{"PositiveReviews":3,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":3},"UserName":"Анелия С."},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 40 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":null,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321666,"Name":"Закрасить поцарапанные места на стене вывески","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"clerical","Address":"улица Кузнецкий Мост, 19с1, Москва","Url":"/t11321666","DateTimeString":"Начать 18 мая, 0:00","DateString":"Начать 18 мая","HideTime":false,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":131506762,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=0\u0026AvatarType=H60W60","Rating":{"PositiveReviews":3,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":3},"UserName":"Мария"},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 3 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":0.879,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321665,"Name":"Погулять с собакой","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"house","Address":"Инициативная улица, 13, Люберцы","Url":"/t11321665","DateTimeString":"Начать 15 мая, 19:00","DateString":"Начать 15 мая","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":132578964,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=7949426\u0026AvatarType=H60W60","Rating":{"PositiveReviews":0,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":0},"UserName":"Максим С."},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до  500","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":19.446,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321664,"Name":"Течет труба","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"clerical","Address":"улица Гамалеи, 1, Москва","Url":"/t11321664","DateTimeString":"Начать 15 мая, 18:10","DateString":"Начать 15 мая","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":132438250,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=0\u0026AvatarType=H60W60","Rating":{"PositiveReviews":0,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":0},"UserName":"Артем И."},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 2 000","IsSbr":true,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":10.66,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321663,"Name":"Помыть пол в бытовке","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"house","Address":"улица Москворечье, Москва","Url":"/t11321663","DateTimeString":"Начать 15 мая, 17:33","DateString":"Начать 15 мая","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":132074496,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=0\u0026AvatarType=H60W60","Rating":{"PositiveReviews":0,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":0},"UserName":"Андрей Ф."},"Viewed":false,"IsRegular":false,"PriceRangeId":13345,"BudgetDescription":"до 2 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":12.471,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321662,"Name":"E-mail рассылка","IsMarker":false,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"virtualassistant","Address":null,"Url":"/t11321662","DateTimeString":"Начать 15 мая, 17:15","DateString":"Начать 15 мая","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":132569762,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=0\u0026AvatarType=H60W60","Rating":{"PositiveReviews":0,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":0},"UserName":"Рада А."},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до  700","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":null,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321659,"Name":"Нужен мастер на час","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"clerical","Address":"Зелёная улица, 42, посёлок Володарского","Url":"/t11321659","DateTimeString":"16 мая, 13:00 — 19 мая, 17:00","DateString":"16 мая — 19 мая","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":126827422,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=6371651\u0026AvatarType=H60W60","Rating":{"PositiveReviews":0,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":0},"UserName":"Полина З."},"Viewed":false,"IsRegular":false,"PriceRangeId":13390,"BudgetDescription":"до 3 000","IsSbr":true,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":34.93,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321657,"Name":"Договориться о публикации релиза в узбекских сми","IsMarker":false,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"virtualassistant","Address":null,"Url":"/t11321657","DateTimeString":"Начать 16 мая, 0:00","DateString":"Начать 16 мая","HideTime":true,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":121778058,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=835531\u0026AvatarType=H60W60","Rating":{"PositiveReviews":5,"NegativeReviews":1,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":6},"UserName":"Ромина М."},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 10 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":null,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321656,"Name":"Отпарить одежду","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"house","Address":"Бумажный проезд, 4, Москва","Url":"/t11321656","DateTimeString":"Начать 15 мая, 18:30","DateString":"Начать 15 мая","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":123835483,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=7949455\u0026AvatarType=H60W60","Rating":{"PositiveReviews":2,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":2},"UserName":"Даниа К."},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 2 500","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":3.913,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321655,"Name":"Webview приложение на айфон","IsMarker":false,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"webdevelopment","Address":null,"Url":"/t11321655","DateTimeString":"Начать 15 мая, 17:32","DateString":"Начать 15 мая","HideTime":true,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":125864328,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=7770844\u0026AvatarType=H60W60","Rating":{"PositiveReviews":27,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":27},"UserName":"Денис С."},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 30 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":null,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321654,"Name":"прочистка труб канализации до 50мм стальным тросом...","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"clerical","Address":"улица 1905 года, Москва","Url":"/t11321654","DateTimeString":"Начать 15 мая, 19:00","DateString":"Начать 15 мая","HideTime":false,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":127866593,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=0\u0026AvatarType=H60W60","Rating":{"PositiveReviews":0,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":0},"UserName":"Андрей К."},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 3 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":3.702,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321653,"Name":"Написать курсовую работу","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"teaching","Address":"Москва","Url":"/t11321653","DateTimeString":"15 мая, 17:29 — 18 мая, 23:59","DateString":"15 мая — 18 мая","HideTime":false,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":132579031,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=0\u0026AvatarType=H60W60","Rating":{"PositiveReviews":0,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":0},"UserName":"Ольга"},"Viewed":false,"IsRegular":true,"PriceRangeId":1,"BudgetDescription":"до 10 000","IsSbr":true,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":0,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321652,"Name":"Сверстать брошюру","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"design","Address":"район Раменки, Москва","Url":"/t11321652","DateTimeString":"Начать 20 мая, 10:30","DateString":"Начать 20 мая","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":132579020,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=0\u0026AvatarType=H60W60","Rating":{"PositiveReviews":0,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":0},"UserName":"Александр К."},"Viewed":false,"IsRegular":false,"PriceRangeId":12556,"BudgetDescription":"до 5 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":7.521,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321651,"Name":"Нужен копирайтер с опытом работы удаленно","IsMarker":false,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"virtualassistant","Address":null,"Url":"/t11321651","DateTimeString":"Начать 15 мая, 17:30","DateString":"Начать 15 мая","HideTime":false,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":130845795,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=7927635\u0026AvatarType=H60W60","Rating":{"PositiveReviews":0,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":0},"UserName":"Рита А."},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 100 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":null,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321650,"Name":"Ремонт паркетного пола в квартире","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"clerical","Address":"район Северное Тушино, Москва","Url":"/t11321650","DateTimeString":"15 мая, 17:30 — 20 мая, 17:35","DateString":"15 мая — 20 мая","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":132579022,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=0\u0026AvatarType=H60W60","Rating":{"PositiveReviews":0,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":0},"UserName":"Ольга"},"Viewed":false,"IsRegular":false,"PriceRangeId":13417,"BudgetDescription":"до 100 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":16.681,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321649,"Name":"Няня для двух детей","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"house","Address":"деревня Новосельцево","Url":"/t11321649","DateTimeString":"Начать 17 мая, 0:00","DateString":"Начать 17 мая","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":123521038,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=0\u0026AvatarType=H60W60","Rating":{"PositiveReviews":16,"NegativeReviews":1,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":17},"UserName":"Алексей"},"Viewed":false,"IsRegular":false,"PriceRangeId":12036,"BudgetDescription":"до 3 000","IsSbr":true,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":27.695,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321648,"Name":"Настроить яндекс директ","IsMarker":false,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"virtualassistant","Address":null,"Url":"/t11321648","DateTimeString":"Начать 16 мая, 17:25","DateString":"Начать 16 мая","HideTime":false,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":128817011,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=4846750\u0026AvatarType=H60W60","Rating":{"PositiveReviews":4,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":4},"UserName":"Евгений Р."},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 4 200","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":null,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11318188,"Name":"Кабельщик","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"clerical","Address":"улица Новаторов, Москва","Url":"/t11318188","DateTimeString":"Начать 16 мая, 0:00","DateString":"Начать 16 мая","HideTime":true,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":125897330,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=7892818\u0026AvatarType=H60W60","Rating":{"PositiveReviews":2,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":2},"UserName":"Никита С."},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 3 005","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":11.875,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321590,"Name":"Подработка пешим курьером или на авто","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"courier","Address":"1-й Магистральный тупик, Москва","Url":"/t11321590","DateTimeString":"Начать 15 мая, 17:10","DateString":"Начать 15 мая","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":130168533,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=4918394\u0026AvatarType=H60W60","Rating":{"PositiveReviews":10,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":10},"UserName":"Евгений"},"Viewed":false,"IsRegular":false,"PriceRangeId":13512,"BudgetDescription":"до 2 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":5.375,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321647,"Name":"Уроки на гитаре","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"teaching","Address":"Серебряный бульвар, Красногорск","Url":"/t11321647","DateTimeString":"Начать 16 мая, 0:00","DateString":"Начать 16 мая","HideTime":false,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":132579025,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=0\u0026AvatarType=H60W60","Rating":{"PositiveReviews":0,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":0},"UserName":"Георгий"},"Viewed":false,"IsRegular":true,"PriceRangeId":1,"BudgetDescription":"до 1 200","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":25.146,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321645,"Name":"Устранить засор в кафе/общепит","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"house","Address":"Большая Семёновская улица, 16, Москва","Url":"/t11321645","DateTimeString":"Начать 15 мая, 17:28","DateString":"Начать 15 мая","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":131931956,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=0\u0026AvatarType=H60W60","Rating":{"PositiveReviews":1,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":1},"UserName":"Лок"},"Viewed":false,"IsRegular":false,"PriceRangeId":13565,"BudgetDescription":"до 2 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":6.131,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321630,"Name":"Вакансия менеджера озон","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"virtualassistant","Address":"Москва","Url":"/t11321630","DateTimeString":"Начать 16 мая, 20:00","DateString":"Начать 16 мая","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":132493673,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=0\u0026AvatarType=H60W60","Rating":{"PositiveReviews":0,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":0},"UserName":"Анна М."},"Viewed":false,"IsRegular":false,"PriceRangeId":1,"BudgetDescription":"до 20 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":0,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]}],"ItemsOnPage":50,"Total":11102,"Stat":{"UserDrafts":0,"UserTasks":0,"UserOrders":0,"UserOffers":0,"UserJobs":0,"OrdersForUser":0},"InsufficientTasksWarning":false},"IsSuccess":true,"Code":0,"Message":"","Timestamp":1684158361551.6382}'

# %%
res
# Out:
# '{"ResultObject":{"Items":[{"Id":11321704,"Name":"Ремонт (чистка) принтера","IsMarker":true,"PriceAmount":0,"StatusText":"Открыто","StatusFlag":"new","CategoryFlag":"computerhelp","Address":"Новинский бульвар, 11Ас1, Москва","Url":"/t11321704","DateTimeString":"Начать 16 мая, 14:00","DateString":"Начать 16 мая","HideTime":null,"IsMine":false,"IsDraft":false,"CreatorInfo":{"Id":126069192,"Avatar":"https://avatar.youdo.com/get.userAvatar?AvatarId=0&AvatarType=H60W60","Rating":{"PositiveReviews":49,"NegativeReviews":0,"PriceScore":0,"QualityScore":0,"PolitenessScore":0,"PunctualityScore":0,"AdequacyScore":0,"SummaryScore":0,"SummaryReviews":49},"UserName":"Мария"},"Viewed":false,"IsRegular":false,"PriceRangeId":12786,"BudgetDescription":"до 2 000","IsSbr":false,"Admission":null,"IsB2B":false,"OffersCount":0,"Distance":2.24,"IsActual":true,"CouponsForPaying":0.00000000000000,"PreferInsuredExecutor":true,"Tags":[]},{"Id":11321703,"Name":"Вечерняя няня для ребенка","IsMarker":true,"PriceAm
# ...

# %%
import json
res = json.loads(res)

# %%
tasks = res['ResultObject']['Items']
categories = {
    'courier' : 0,
    'house' : 1,
    'clerical' : 3,
    'virtualassistant' : 4,
    'computerhelp' : 5,
    'design' : 7,
    'webdevelopment' : 8,
    'healthandbeauty' : 11,
    'techrepair' : 12,
    'legaladvice' : 13,
    'teaching' : 14,
    'auto' : 15
}

names = []
cats = []

for task in tasks:
    name = task['Name']
    names.append(name)
    cats.append(categories[task["CategoryFlag"]])

# %%
print(len(names))
# Out:
# 50

# %%
import random
import psycopg2
import pandas
from datetime import datetime as DT
from datetime import timedelta

def get_random_date(start, end):
    delta = end - start
    return start + timedelta(random.randint(0, delta.days))


# fill task!

conn = psycopg2.connect(user='postgres', password='1234', host='localhost', port='5432', database="youdo")
cur = conn.cursor()

# get user ids
user_ids_query = "SELECT user_id FROM \"user\""
cur.execute(user_ids_query)
res = cur.fetchall()
user_ids = []
for k in res:
    user_ids.append(k[0])


for i in range(len(names)):
    
    # get category_id and estimated_cost_id
    query = f"SELECT cost_id, category_id FROM estimated_cost WHERE category_id = {cats[i] + 51}"
    cur.execute(query)
    res = cur.fetchall()
    pair_ids = []
    for k in res:
        pair_ids.append(k)

    
    # choosing task status, author and performer ids
    if(random.randint(0, 100) > 99):
        task_status = "published"
    else:
        if(random.randint(1, 100) > 99):
            task_status = "in process"
        else:
            task_status = "done"
    id1 = random.choice(user_ids)
    # choosing category and cost
    if(len(pair_ids) == 0):
        continue
    estimated_cost_id, category_id = random.choice(pair_ids)
    # choose start and end time
    start_time = str(random.choice(pandas.date_range('2023-02-01', '2023-03-31')))[:-9]
    end_time = str(random.choice(pandas.date_range(start_time, '2023-04-02')))[:-9]
    #generate name
    NAME_1 = ["Tricky", "Unusual", "Good", "Hard", "Grand", "Careful", "Quick", "Important", "Easy", "Small", "Big"]
    NAME_2 = ["work", "task", "job", "case"]
    #name = random.choice([f"{random.choice(NAME_1)} {random.choice(NAME_2)}", 
    #                      f"Help with {random.choice(NAME_1).lower()}"\
    #                      f" {random.choice(NAME_2)}"])
    description = f"I need {random.choice(['help to', 'a professional to','a person to', 'to'])} "\
                f"do some {random.choice(NAME_1).lower()} {random.choice(NAME_2)} "\
                f"and also I {random.choice(['need materials', 'have busy schedule','need to get some advices','have an angry dog','live far from metro', 'do not have much time'])}"
    task_query = f"INSERT INTO task(\"name\", description, begin_time, "\
    f"end_time, status, author_id, estimated_cost_id) VALUES "\
    f"('{names[i]}', \'{description}\', '{start_time}', '{end_time}', "\
    f" '{task_status}', {id1}, {estimated_cost_id})" 
    task_query += ' RETURNING task_id'
    cur.execute(task_query)
    task_id = cur.fetchall()[0][0]
    
    resp_cnt = random.choice(range(15))
    
    if(resp_cnt == 0): 
        continue
    
    for j in range(resp_cnt):
        author_id = id1
        while (author_id == id1):
            author_id = random.choice(user_ids)
        description = f'{random.choice(["I will", "Let us", "I am glad to", "I am ready to"])}'\
                    f' {random.choice(["do", "solve", "deal with"])} this'\
                    f' {random.choice(NAME_1).lower()} {random.choice(NAME_2)}.'
        query = f"SELECT interval_begin::numeric::int, interval_end::numeric::int, response_cost::numeric::int FROM estimated_cost WHERE cost_id = {estimated_cost_id}"
        cur.execute(query)
        f = cur.fetchone()
        
        cost_begin = f[0]
        cost_end = f[1]
        if(type(cost_begin) != type(1)):
            cost_begin = 0
        if(type(cost_end) != type(1)):
            cost_end = 3*cost_begin
        cost = random.choice(range(cost_begin, cost_end))
        
        response_cost = f[2]
        query = f"SELECT account::numeric::int FROM \"user\" WHERE user_id = {author_id}"
        cur.execute(query)
        current_account = cur.fetchone()[0]
        if(current_account < response_cost): 
            continue
        
        response_query = f'INSERT INTO response(description, \"cost\", author_id, task_id) VALUES'\
        f"(\'{description}\', {cost}, {author_id}, {task_id}) RETURNING response_id"
        cur.execute(response_query)
        response_id = cur.fetchone()[0] 
        
        account_query = f"UPDATE \"user\" SET account={int(current_account) - response_cost} WHERE user_id={author_id}"
        cur.execute(account_query)
        start_dt = DT.strptime('01.04.2023', '%d.%m.%Y')
        end_dt = DT.strptime('15.04.2023', '%d.%m.%Y')
        outgo_date = str(get_random_date(start_dt, end_dt))[0:10]
        transaction_query = f"INSERT INTO \"transaction\""\
        "(timestamp, \"size\", \"type\", status, account_id, response_id) VALUES "\
        f"('{outgo_date}', {response_cost}, 'outgoing', 'done', {author_id}, {response_id})"
        cur.execute(transaction_query)
        
    if(task_status == "published"): 
        continue
    
    cur.execute(f"SELECT response_id FROM response WHERE task_id = {task_id}")
    res = cur.fetchall()
    resp_ids = []
    for i in res:
        resp_ids.append(i[0])
    if(len(resp_ids) == 0):
        continue
    assigned_response = random.choice(resp_ids)
    cur.execute(f"UPDATE task SET assigned_response_id = {assigned_response} WHERE task_id = {task_id}")
        
    if(task_status == "in process"): 
        continue
    
    query = f"SELECT \"cost\"::numeric::int, author_id FROM response WHERE response_id = {assigned_response}"
    cur.execute(query)
    res = cur.fetchone()
    cost = res[0]
    worker_id = res[1]
    
    cur.execute(f"SELECT account::numeric::int FROM \"user\" WHERE user_id={id1}")
    customer_before = cur.fetchone()[0]
    if(cost > customer_before):
        cur.execute(f"UPDATE task SET status = 'in process' WHERE task_id = {task_id}")
        continue
    cur.execute(f"SELECT account::numeric::int FROM \"user\" WHERE user_id={worker_id}")
    worker_before = cur.fetchone()[0]
    start_dt = DT.strptime('01.04.2023', '%d.%m.%Y')
    end_dt = DT.strptime('01.05.2023', '%d.%m.%Y')
    outgo_date = str(get_random_date(start_dt, end_dt))[0:10]
    account_query1 = f"UPDATE \"user\" SET account={int(customer_before) - cost} WHERE user_id={id1}"
    account_query2 = f"UPDATE \"user\" SET account={int(worker_before) + cost} WHERE user_id={worker_id}"
    transaction_query = f"INSERT INTO \"transaction\""\
    "(timestamp, \"size\", \"type\", status, account_id, response_id) VALUES "\
    f"('{outgo_date}', {cost}, 'outgoing', 'done', {id1}, {assigned_response}), "\
    f"('{outgo_date}', {cost}, 'incoming', 'done', {worker_id}, {assigned_response})"
    cur.execute(account_query1)
    cur.execute(account_query2)
    cur.execute(transaction_query)    
    
conn.commit()
cur.close()
conn.close()

# %%
bs = BeautifulSoup(response.content,"html.parser")

# %%
text = response.text
text
# Out:
# '<!DOCTYPE html><html><head><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/><meta name="msapplication-TileColor" content="#da532c"/><meta name="theme-color" content="#ffffff"/><meta name="description" content="Сервис YouDo (Юду) поможет быстро найти надежных специалистов различных областей: курьеры, мастера по ремонту, клинеры, тренеры, репетиторы, мастера красоты и пр. – более 1 500 000 исполнителей."/><meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=yes"/><meta property="fb:app_id" content="141970832520341"/><link rel="preload" href="https://assets.youdo.com/static/fonts/lato/lato-regular-youdo-main.woff2" as="font" type="font/woff2" crossorigin="anonymous"/><link rel="preload" href="https://assets.youdo.com/static/fonts/lato/lato-black-youdo-main.woff2" as="font" type="font/woff2" crossorigin="anonymous"/><link rel="preload" href="https://assets.youdo.com/static/fonts/lat
# ...

# %%
bs1 = bs.body.div.div
bs2 = bs1.contents[1]

# %%
bs1.descendants[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 bs1.descendants[0]
#
# TypeError: 'generator' object is not subscriptable

# %%
text = str(bs)
text
# Out:
# '<!DOCTYPE html>\n<html><head><meta charset="utf-8"/><meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/><meta content="#da532c" name="msapplication-TileColor"/><meta content="#ffffff" name="theme-color"/><meta content="Сервис YouDo (Юду) поможет быстро найти надежных специалистов различных областей: курьеры, мастера по ремонту, клинеры, тренеры, репетиторы, мастера красоты и пр. – более 1 500 000 исполнителей." name="description"/><meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=yes" name="viewport"/><meta content="141970832520341" property="fb:app_id"/><link as="font" crossorigin="anonymous" href="https://assets.youdo.com/static/fonts/lato/lato-regular-youdo-main.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="https://assets.youdo.com/static/fonts/lato/lato-black-youdo-main.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="https://assets.youd
# ...

# %%
subCategories = text[text.find('subCategories'): text.find('link":null,"isDefau')]
names = []
last = subCategories
while("name" in last):
    start = last.find("name")+7
    end = last[start:-1].find('"') + start
    names.append(last[start:end])
    last = last[end:]

# %%
names
# Out:
# ['Бухгалтерские услуги',
#  'Техническое обслуживание автомобиля',
#  'Перевозка вещей, переезды',
#  'Русский язык и литература',
#  'Услуги пешего курьера',
#  'Поддерживающая уборка',
#  'Холодильники и морозильные камеры',
#  'Мастер на час',
#  'Ремонт компьютеров и ноутбуков',
#  'Работа с текстом, копирайтинг',
#  'Услуги косметолога',
#  'Фотосъемка',
#  'Помощь в проведении мероприятий',
#  'Планшеты и телефоны',
#  'Сайт под ключ',
#  'Фирменный стиль, логотипы, визитки',
#  'Разработка мобильных приложений',
#  'Полиграфический дизайн',
#  'Аудиотехника и системы',
#  'Генеральная уборка',
#  'Раздача промо-материалов',
#  'Видеосъемка',
#  'Установка и настройка операц. систем, программ',
#  'Ремонт под ключ',
#  'Услуги курьера на легковом авто',
#  'Стиральные и сушильные машины',
#  'Английский язык',
#  'Диагностика и ремонт двигателя, КПП и ходовой части',
#  'Консультация специалиста по налогам',
#  'Эпиляция',
#  'Услуги переводчика',
#  'Брови и ресницы',
# ...

# %%
<div class="Categories_catName__3MAsf">Курьерские услуги<span class="Categories_catCount__-HfdW hidden">&nbsp;[0]</span></div>
# Out:
# None

# %%
<li class="Categories_item__3YeiZ"><div class="Categories_catName__3MAsf">Курьерские услуги<span class="Categories_catCount__-HfdW hidden">&nbsp;[0]</span></div><span class="Categories_arrow__1Wnl_"></span><div class="Checkbox_container__3Hb6D Categories_checkbox__svhXf Checkbox_mobileTransform__1zhAu"><input class="Checkbox_checkbox__23g8L" type="checkbox" id="v8y3e0te" value="16384"><span class="Checkbox_checkboxIcon__2BZMU"></span><label class="Checkbox_label__2fQMZ" for="v8y3e0te">Курьерские услуги</label></div><ul class="Categories_subList__3zp1Q hidden"><li class="Categories_subItem__K5Ra0"><div class="Checkbox_container__3Hb6D Checkbox_mobileTransform__1zhAu"><input class="Checkbox_checkbox__23g8L" type="checkbox" id="c1hn7cbv" value="1"><span class="Checkbox_checkboxIcon__2BZMU"></span><label class="Checkbox_label__2fQMZ" for="c1hn7cbv">Услуги пешего курьера</label></div></li><li class="Categories_subItem__K5Ra0"><div class="Checkbox_container__3Hb6D Checkbox_mobileTransform__1zhAu"><input class="Checkbox_checkbox__23g8L" type="checkbox" id="xuvxkt8f" value="2"><span class="Checkbox_checkboxIcon__2BZMU"></span><label class="Checkbox_label__2fQMZ" for="xuvxkt8f">Услуги курьера на легковом авто</label></div></li><li class="Categories_subItem__K5Ra0"><div class="Checkbox_container__3Hb6D Checkbox_mobileTransform__1zhAu"><input class="Checkbox_checkbox__23g8L" type="checkbox" id="s5y807ec" value="124"><span class="Checkbox_checkboxIcon__2BZMU"></span><label class="Checkbox_label__2fQMZ" for="s5y807ec">Купить и доставить</label></div></li><li class="Categories_subItem__K5Ra0"><div class="Checkbox_container__3Hb6D Checkbox_mobileTransform__1zhAu"><input class="Checkbox_checkbox__23g8L" type="checkbox" id="dqe8xwub" value="123"><span class="Checkbox_checkboxIcon__2BZMU"></span><label class="Checkbox_label__2fQMZ" for="dqe8xwub">Срочная доставка</label></div></li><li class="Categories_subItem__K5Ra0"><div class="Checkbox_container__3Hb6D Checkbox_mobileTransform__1zhAu"><input class="Checkbox_checkbox__23g8L" type="checkbox" id="z6dgk5wq" value="125"><span class="Checkbox_checkboxIcon__2BZMU"></span><label class="Checkbox_label__2fQMZ" for="z6dgk5wq">Доставка продуктов</label></div></li><li class="Categories_subItem__K5Ra0"><div class="Checkbox_container__3Hb6D Checkbox_mobileTransform__1zhAu"><input class="Checkbox_checkbox__23g8L" type="checkbox" id="cj28okjp" value="126"><span class="Checkbox_checkboxIcon__2BZMU"></span><label class="Checkbox_label__2fQMZ" for="cj28okjp">Доставка еды из ресторанов</label></div></li><li class="Categories_subItem__K5Ra0"><div class="Checkbox_container__3Hb6D Checkbox_mobileTransform__1zhAu"><input class="Checkbox_checkbox__23g8L" type="checkbox" id="ulr35pkc" value="127"><span class="Checkbox_checkboxIcon__2BZMU"></span><label class="Checkbox_label__2fQMZ" for="ulr35pkc">Курьер на день</label></div></li><li class="Categories_subItem__K5Ra0"><div class="Checkbox_container__3Hb6D Checkbox_mobileTransform__1zhAu"><input class="Checkbox_checkbox__23g8L" type="checkbox" id="p4cccc8n" value="104"><span class="Checkbox_checkboxIcon__2BZMU"></span><label class="Checkbox_label__2fQMZ" for="p4cccc8n">Другая посылка</label></div></li></ul></li>

# %%
import urllib.request

fp = urllib.request.urlopen("https://youdo.com/tasks-all-opened-all")
mybytes = fp.read()

mystr = mybytes.decode("utf8")
fp.close()

print(mystr)
# Out:
# <!DOCTYPE html><html><head><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/><meta name="msapplication-TileColor" content="#da532c"/><meta name="theme-color" content="#ffffff"/><meta name="description" content="Сервис YouDo (Юду) поможет быстро найти надежных специалистов различных областей: курьеры, мастера по ремонту, клинеры, тренеры, репетиторы, мастера красоты и пр. – более 1 500 000 исполнителей."/><meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=yes"/><meta property="fb:app_id" content="141970832520341"/><link rel="preload" href="https://assets.youdo.com/static/fonts/lato/lato-regular-youdo-main.woff2" as="font" type="font/woff2" crossorigin="anonymous"/><link rel="preload" href="https://assets.youdo.com/static/fonts/lato/lato-black-youdo-main.woff2" as="font" type="font/woff2" crossorigin="anonymous"/><link rel="preload" href="https://assets.youdo.com/static/fonts/lato
# ...

# %%
mystr.find('Categories_catName')
# Out:
# -1
